# %% [markdown]
# # Image Preprocessing
# * Perform cropping to ROi
# * Perform colour extraction
# * Saving to preprocessed directory

# %%
# import libraries
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import sys


# for waveform analysis
TEST_DATASET_PATH = "E:\\Data\\TestSet\\"
TEST_CATEGORIES = ['OverSaturated', 'UnderSaturated', 'JustSaturated']

MODEL_PATH = 'E:\\Model\\'
CNN_PREPROCESSING_BUFFER_PATH = 'E:\\Data\\PreprocessingBuffer\\'
FAILED_TESTCASES_PATH = "E:\\Data\\Failed Testset\\"
CROPPED_DATASET_PATH = 'E:\\Data\\LargeSet\\Cropped\\'

OVERSATURATED_DATASET_PATH = 'E:\\Data\\LargeSet\\OverSaturated'
UNDERSATURATED_DATASET_PATH = 'E:\\Data\\LargeSet\\UnderSaturated'
JUSTSATURATED_DATASET_PATH = 'E:\\Data\\LargeSet\\JustSaturated'

OVERSATURATED_CROPPED_DATASET_PATH = 'E:\\Data\\LargeSet\\Cropped\\OverSaturated'
UNDERSATURATED_CROPPED_DATASET_PATH = 'E:\\Data\\LargeSet\\Cropped\\UnderSaturated'
JUSTSATURATED_CROPPED_DATASET_PATH = 'E:\\Data\\LargeSet\\Cropped\\JustSaturated'

# %%
# path to image folder
overSaturated_image_dir = OVERSATURATED_DATASET_PATH
justSaturated_image_dir = JUSTSATURATED_DATASET_PATH
underSaturated_image_dir = UNDERSATURATED_DATASET_PATH

# path to cropped image folder
overSaturated_cropped_dir = OVERSATURATED_CROPPED_DATASET_PATH
justSaturated_cropped_dir = JUSTSATURATED_CROPPED_DATASET_PATH
underSaturated_cropped_dir = UNDERSATURATED_CROPPED_DATASET_PATH

# create directories if they don't exist
if not os.path.exists(overSaturated_cropped_dir):
    os.makedirs(overSaturated_cropped_dir)

if not os.path.exists(justSaturated_cropped_dir):
    os.makedirs(justSaturated_cropped_dir)

if not os.path.exists(underSaturated_cropped_dir):
    os.makedirs(underSaturated_cropped_dir)

# %%
# Region of Interest (ROI) coordinates
x_start, x_end, y_start, y_end = 600, 1270, 60, 300

# %%
# open a image for previewing
img = cv2.imread(os.path.join(overSaturated_image_dir, 'overSaturated0.bmp.bmp'))

# Convert the image from BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# crop the image
img_cropped = img[y_start:y_end, x_start:x_end]

# show the image
plt.imshow(img_cropped)
plt.show()

# %%
# read all the images in the JustSaturated folder
for file in os.listdir(justSaturated_image_dir):
    # read the image
    img = cv2.imread(os.path.join(justSaturated_image_dir, file))

    # crop the image to ROI
    img_cropped = img[y_start:y_end, x_start:x_end]

    # save the image with original file name
    cv2.imwrite(os.path.join(justSaturated_cropped_dir, file), img_cropped)

# %%
# read all the images in the OverSaturated folder
for i, file in enumerate(os.listdir(overSaturated_image_dir)):
    # read the image
    img = cv2.imread(os.path.join(overSaturated_image_dir, file))

    # crop the image to ROI
    img_cropped = img[y_start:y_end, x_start:x_end]

    # save the image
    cv2.imwrite(os.path.join(overSaturated_cropped_dir, file), img_cropped)

# %%
# read all the images in the UnderSaturated folder
for i, file in enumerate(os.listdir(underSaturated_image_dir)):
    # read the image
    img = cv2.imread(os.path.join(underSaturated_image_dir, file))

    # crop the image to ROI
    img_cropped = img[y_start:y_end, x_start:x_end]

    # save the image
    cv2.imwrite(os.path.join(underSaturated_cropped_dir, file), img_cropped)

# %%
import os
import cv2
import matplotlib.pyplot as plt
import sys

# Define the path to the main directory
main_dir = "E:\\RDI Dataset\\"
oversaturate_dir = "E:\\RDI Dataset\\Oversaturated"
undersaturate_dir = "E:\\RDI Dataset\\Undersaturated"
justsaturated_dir = "E:\\RDI Dataset\\JustSaturated"

# Region of Interest (ROI) coordinates
x_start, x_end, y_start, y_end = 600, 1270, 60, 300

# Function to handle cropping
def handle_cropping(image_dir, target_dir):
    # Check if the cropped directory exists, if not, create it
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
        
    # Process each image file in the image directory
    for file in os.listdir(image_dir):
        # Check if the file is an image
        if file.endswith(".bmp") or file.endswith(".jpg") or file.endswith(".png"):
            # Read the image
            img = cv2.imread(os.path.join(image_dir, file))
            
            # Crop the image to the ROI
            img_cropped = img[y_start:y_end, x_start:x_end]
            
            # Save the cropped image in the cropped directory
            cv2.imwrite(os.path.join(target_dir, file), img_cropped)

            print("Cropped image " + file + " to " + target_dir)

def main():
    # Loop through each subdirectory in the main directory
    for subdir in os.listdir(main_dir):
        subdir_path = os.path.join(main_dir, subdir)

        # Check if the path is a directory
        if os.path.isdir(subdir_path):
            # Define the paths to the image directory and the cropped directory
            image_dir = subdir_path

            # Determine the target directory based on the subdirectory name
            if "Light Level" in subdir:
                light_level = int(subdir.split(" ")[-1])
                if light_level <= 35:
                    #target_dir = undersaturate_dir
                    # Handle the cropping for this directory
                    #handle_cropping(image_dir, target_dir)
                    pass
                elif light_level <= 38:
                    #target_dir = justsaturated_dir
                    # Handle the cropping for this directory
                    #handle_cropping(image_dir, target_dir)
                    pass
                else:
                    target_dir = oversaturate_dir
                    handle_cropping(image_dir, target_dir)
            else:
                pass

            

if __name__ == "__main__":
    main()
# Out:
# Cropped image light_level_39_1.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_2.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_3.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_4.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_5.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_6.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_7.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_8.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_9.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_10.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_11.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_12.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_13.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_14.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_15.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_16.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_17.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_18.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_19.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_20.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_21.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_22.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_23.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_24.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_25.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_26.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_27.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_28.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_29.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_30.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_31.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_32.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_33.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_34.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_35.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_36.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_37.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_38.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_39.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_40.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_41.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_42.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_43.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_44.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_45.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_46.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_47.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_48.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_49.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_50.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_51.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_52.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_39_53.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level
bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1961.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1962.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1963.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1964.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1965.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1966.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1967.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1968.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1969.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1970.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1971.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1972.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1973.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1974.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1975.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1976.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1977.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1978.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1979.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1980.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1981.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1982.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1983.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1984.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1985.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1986.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1987.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1988.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1989.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1990.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1991.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1992.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1993.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1994.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1995.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1996.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1997.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1998.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_1999.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2000.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2001.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2002.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2003.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2004.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2005.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2006.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2007.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2008.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2009.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2010.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2011.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2012.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2013.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2014.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2015.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2016.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2017.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2018.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2019.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2020.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2021.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2022.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2023.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2024.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2025.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2026.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2027.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2028.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2029.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2030.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2031.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2032.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2033.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2034.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2035.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2036.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2037.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2038.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2039.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2040.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2041.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2042.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2043.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2044.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2045.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2046.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2047.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2048.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2049.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2050.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2051.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2052.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2053.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2054.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2055.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2056.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2057.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2058.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2059.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2060.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2061.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2062.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2063.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2064.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2065.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2066.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2067.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2068.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2069.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2070.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2071.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2072.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2073.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2074.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2075.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2076.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2077.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2078.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2079.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2080.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2081.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2082.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2083.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2084.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2085.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2086.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2087.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2088.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2089.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2090.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2091.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2092.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2093.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2094.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2095.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2096.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2097.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2098.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2099.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2100.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2101.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2102.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2103.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2104.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2105.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2106.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2107.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2108.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2109.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2110.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2111.bmp to E:\RDI Dataset\Oversaturated
# Cropped image light_level_100_2112.bmp to E:\RDI Dataset\Oversaturated
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 68
#      63                 pass
#      67 if __name__ == "__main__":
# ---> 68     main()
#
# Cell In[1], line 61, in main()
#      59     else:
#      60         target_dir = oversaturate_dir
# ---> 61         handle_cropping(image_dir, target_dir)
#      62 else:
#      63     pass
#
# Cell In[1], line 26, in handle_cropping(image_dir, target_dir)
#      22 for file in os.listdir(image_dir):
#      23     # Check if the file is an image
#      24     if file.endswith(".bmp") or file.endswith(".jpg") or file.endswith(".png"):
#      25         # Read the image
# ---> 26         img = cv2.imread(os.path.join(image_dir, file))
#      28         # Crop the image to the ROI
#      29         img_cropped = img[y_start:y_end, x_start:x_end]
#
# KeyboardInterrupt:
